# %%
# Define Neo4j connections
from neo4j import GraphDatabase
import pandas as pd
import numpy

# %%
host = 'bolt://localhost:7687'
user = 'neo4j'
password = '12345678'
database = 'dbms2'

# %%
driver = GraphDatabase.driver(host,auth=(user, password), database=database)
                                         

def run_query(query, params={}):
    with driver.session() as session:
        result = session.run(query, params)
        return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
data = run_query("""
MATCH (s)-[r]->(t)
RETURN toString(id(s)) as source, toString(id(t)) AS target, type(r) as type
""")

# %%
data.head()
# Out:
#   source target       type
# 0      0  12590  interacts
# 1      0   8752  interacts
# 2      0   7915  interacts
# 3      0  21711  interacts
# 4      0   6447  interacts

# %%
from pykeen.triples import TriplesFactory


tf = TriplesFactory.from_labeled_triples(
  data[["source", "type", "target"]].values,
  create_inverse_triples=False,
  entity_to_id=None,
  relation_to_id=None,
  compact_id=False,
  filter_out_candidate_inverse_relations=True,
  metadata=None,
)

# %%
training, testing, validation = tf.split([.8, .1, .1])
# Out:
# using automatically assigned random_state=4156377184

# %% [markdown]
# # Running ComplEx,TransE and ConvE models

# %%
from pykeen.pipeline import pipeline

result = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='ComplEx',
    stopper='early',
    epochs=3,
    dimensions=512,
    random_seed=420

)
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: C:\Users\shubh\.data\pykeen\checkpoints\best-model-weights-a46415ec-4c39-4630-8f2d-6a8645046df1.pt
# Training epochs on cpu:   0%|          | 0/3 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/56.3k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 847.32s seconds

# %%
result2 = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='TransE',
    stopper='early',
    epochs=3,
    dimensions=512,
    random_seed=420

)
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: C:\Users\shubh\.data\pykeen\checkpoints\best-model-weights-b07b9ea3-2fad-4879-87f1-de8a1c4d830a.pt
# Training epochs on cpu:   0%|          | 0/3 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1759 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/56.3k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 595.62s seconds

# %%
result3 = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='ConvE',
    stopper='early',
    epochs=3,
    dimensions=512,
    random_seed=420

)
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# WARNING:pykeen.models.unimodal.conv_e:
# The ConvE model should be trained with inverse triples.
# This can be done by defining the TriplesFactory class with the _create_inverse_triples_ parameter set to true.
# INFO:pykeen.nn.modules:Resolving None * None * None = 200.
# INFO:pykeen.nn.modules:Resolved to 1 * 20 * 10 = 200.
# INFO:pykeen.stoppers.early_stopping:Inferred checkpoint path for best model weights: C:\Users\shubh\.data\pykeen\checkpoints\best-model-weights-f6947946-1abf-4e66-9b43-e7984e2592ae.pt
# Training epochs on cpu:   0%|          | 0/3 [00:00<?, ?epoch/s]
# INFO:pykeen.training.training_loop:Dropping last (incomplete) batch each epoch (1/1758 (0.06%) batches).
# Training batches on cpu:   0%|          | 0/1758 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1758 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0/1758 [00:00<?, ?batch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu:   0%|          | 0.00/56.3k [00:00<?, ?triple/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result3 = pipeline(
#       2     training=training,
#       3     testing=testing,
#       4     validation=validation,
#       5     model='ConvE',
#       6     stopper='early',
#       7     epochs=3,
#       8     dimensions=512,
#       9     random_seed=420
#      10
#      11 )
#
# File ~\anaconda3\lib\site-packages\pykeen\pipeline\api.py:1562, in pipeline(dataset, dataset_kwargs, training, testing, validation, evaluation_entity_whitelist, evaluation_relation_whitelist, model, model_kwargs, interaction, interaction_kwargs, dimensions, loss, loss_kwargs, regularizer, regularizer_kwargs, optimizer, optimizer_kwargs, clear_optimizer, lr_scheduler, lr_scheduler_kwargs, training_loop, training_loop_kwargs, negative_sampler, negative_sampler_kwargs, epochs, training_kwargs, stopper, stopper_kwargs, evaluator, evaluator_kwargs, evaluation_kwargs, result_tracker, result_tracker_kwargs, metadata, device, random_seed, use_testing_data, evaluation_fallback, filter_validation_when_testing, use_tqdm)
#    1539 evaluator_instance, evaluation_kwargs = _handle_evaluator(
#    1540     _result_tracker=_result_tracker,
#    1541     evaluator=evaluator,
#    1542     evaluator_kwargs=evaluator_kwargs,
#    1543     evaluation_kwargs=evaluation_kwargs,
#    1544 )
#    1546 stopper_instance, configuration, losses, train_seconds = _handle_training(
#    1547     _result_tracker=_result_tracker,
#    1548     training=training,
#    (...)
#    1559     use_tqdm=use_tqdm,
#    1560 )
# -> 1562 metric_results, evaluate_seconds = _handle_evaluation(
#    1563     _result_tracker=_result_tracker,
#    1564     model_instance=model_instance,
#    1565     evaluator_instance=evaluator_instance,
#    1566     stopper_instance=stopper_instance,
#    1567     training=training,
#    1568     testing=testing,
#    1569     validation=validation,
#    1570     training_kwargs=training_kwargs,
#    1571     evaluation_kwargs=evaluation_kwargs,
#    1572     use_testing_data=use_testing_data,
#    1573     evaluation_fallback=evaluation_fallback,
#    1574     filter_validation_when_testing=filter_validation_when_testing,
#    1575     use_tqdm=use_tqdm,
#    1576 )
#    1577 _result_tracker.end_run()
#    1579 return PipelineResult(
#    1580     random_seed=_random_seed,
#    1581     model=model_instance,
#    (...)
#    1590     evaluate_seconds=evaluate_seconds,
#    1591 )
#
# File ~\anaconda3\lib\site-packages\pykeen\pipeline\api.py:1286, in _handle_evaluation(_result_tracker, model_instance, evaluator_instance, stopper_instance, training, testing, validation, training_kwargs, evaluation_kwargs, use_testing_data, evaluation_fallback, filter_validation_when_testing, use_tqdm)
#    1277 _result_tracker.log_params(
#    1278     params=dict(
#    1279         evaluation_kwargs={
#    (...)
#    1283     )
#    1284 )
#    1285 evaluate_start_time = time.time()
# -> 1286 metric_results: MetricResults = _safe_evaluate(
#    1287     model=model_instance,
#    1288     mapped_triples=mapped_triples,
#    1289     evaluator=evaluator_instance,
#    1290     evaluation_kwargs=evaluation_kwargs,
#    1291     evaluation_fallback=evaluation_fallback,
#    1292 )
#    1293 evaluate_end_time = time.time() - evaluate_start_time
#    1294 step = training_kwargs.get("num_epochs")
#
# File ~\anaconda3\lib\site-packages\pykeen\pipeline\api.py:1627, in _safe_evaluate(model, mapped_triples, evaluator, evaluation_kwargs, evaluation_fallback)
#    1624 except (MemoryError, RuntimeError) as e:
#    1625     # If the evaluation still fail using the CPU, the error is raised
#    1626     if model.device.type != "cuda" or not evaluation_fallback:
# -> 1627         raise e
#    1629     # When the evaluation failed due to OOM on the GPU due to a batch size set too high, the evaluation is
#    1630     # restarted with PyKEEN's automatic memory optimization
#    1631     elif "batch_size" in evaluation_kwargs:
#
# File ~\anaconda3\lib\site-packages\pykeen\pipeline\api.py:1619, in _safe_evaluate(model, mapped_triples, evaluator, evaluation_kwargs, evaluation_fallback)
#    1617 while True:
#    1618     try:
# -> 1619         metric_results: MetricResults = evaluator.evaluate(
#    1620             model=model,
#    1621             mapped_triples=mapped_triples,
#    1622             **evaluation_kwargs,
#    1623         )
#    1624     except (MemoryError, RuntimeError) as e:
#    1625         # If the evaluation still fail using the CPU, the error is raised
#    1626         if model.device.type != "cuda" or not evaluation_fallback:
#
# File ~\anaconda3\lib\site-packages\pykeen\evaluation\evaluator.py:213, in Evaluator.evaluate(self, model, mapped_triples, batch_size, slice_size, **kwargs)
#     210         # Clear the ranks from the current evaluator
#     211         self.clear()
# --> 213 rv = evaluate(
#     214     model=model,
#     215     mapped_triples=mapped_triples,
#     216     evaluator=self,
#     217     batch_size=batch_size,
#     218     slice_size=slice_size,
#     219     **kwargs,
#     220 )
#     221 # Since squeeze is true, we can expect that evaluate returns a MetricResult, but we need to tell MyPy that
#     222 return cast(MetricResults, rv)
#
# File ~\anaconda3\lib\site-packages\pykeen\evaluation\evaluator.py:687, in evaluate(model, mapped_triples, evaluator, only_size_probing, batch_size, slice_size, device, use_tqdm, tqdm_kwargs, restrict_entities_to, restrict_relations_to, do_time_consuming_checks, additional_filter_triples, pre_filtered_triples, targets, mode)
#     685 relation_filter = None
#     686 for target in targets:
# --> 687     relation_filter = _evaluate_batch(
#     688         batch=batch,
#     689         model=model,
#     690         target=target,
#     691         evaluator=evaluator,
#     692         slice_size=slice_size,
#     693         all_pos_triples=all_pos_triples,
#     694         relation_filter=relation_filter,
#     695         restrict_entities_to=restrict_entities_to,
#     696         mode=mode,
#     697     )
#     699 # If we only probe sizes we do not need more than one batch
#     700 if only_size_probing and evaluated_once:
#
# File ~\anaconda3\lib\site-packages\pykeen\evaluation\evaluator.py:760, in _evaluate_batch(batch, model, target, evaluator, slice_size, all_pos_triples, relation_filter, restrict_entities_to, mode)
#     720 def _evaluate_batch(
#     721     batch: MappedTriples,
#     722     model: Model,
#    (...)
#     730     mode: Optional[InductiveMode],
#     731 ) -> torch.BoolTensor:
#     732     """
#     733     Evaluate ranking for batch.
#     734
#    (...)
#     758         The relation filter, which can be re-used for the same batch.
#     759     """
# --> 760     scores = model.predict(hrt_batch=batch, target=target, slice_size=slice_size, mode=mode)
#     762     if evaluator.filtered or evaluator.requires_positive_mask:
#     763         column = TARGET_TO_INDEX[target]
#
# File ~\anaconda3\lib\site-packages\pykeen\models\base.py:481, in Model.predict(self, hrt_batch, target, full_batch, ids, **kwargs)
#     479     if full_batch:
#     480         hrt_batch = hrt_batch[:, 1:3]
# --> 481     return self.predict_h(hrt_batch, **kwargs, heads=ids)
#     483 raise ValueError(f"Unknown target={target}")
#
# File ~\anaconda3\lib\site-packages\pykeen\models\base.py:374, in Model.predict_h(self, rt_batch, **kwargs)
#     372     scores = self.score_h_inverse(rt_batch=rt_batch, **kwargs)
#     373 else:
# --> 374     scores = self.score_h(rt_batch, **kwargs)
#     375 if self.predict_with_sigmoid:
#     376     scores = torch.sigmoid(scores)
#
# File ~\anaconda3\lib\site-packages\pykeen\models\nbase.py:527, in ERModel.score_h(self, rt_batch, slice_size, mode, heads)
#     524 if heads is None or heads.ndimension() == 1:
#     525     h = parallel_unsqueeze(h, dim=0)
#     526 return repeat_if_necessary(
# --> 527     scores=self.interaction.score(h=h, r=r, t=t, slice_size=slice_size, slice_dim=1),
#     528     representations=self.entity_representations,
#     529     num=self._get_entity_len(mode=mode) if heads is None else heads.shape[-1],
#     530 )
#
# File ~\anaconda3\lib\site-packages\pykeen\nn\modules.py:265, in Interaction.score(self, h, r, t, slice_size, slice_dim)
#     243 """Compute broadcasted triple scores with optional slicing.
#     244
#     245 .. note ::
#    (...)
#     262     The scores.
#     263 """
#     264 if slice_size is None:
# --> 265     return self(h=h, r=r, t=t)
#     267 return torch.cat(
#     268     [
#     269         self(h=h_batch, r=r_batch, t=t_batch)
#    (...)
#     272     dim=slice_dim,
#     273 )
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\pykeen\nn\modules.py:412, in FunctionalInteraction.forward(self, h, r, t)
#     394 def forward(
#     395     self,
#     396     h: HeadRepresentation,
#     397     r: RelationRepresentation,
#     398     t: TailRepresentation,
#     399 ) -> torch.FloatTensor:
#     400     """Compute broadcasted triple scores given broadcasted representations for head, relation and tails.
#     401
#     402     :param h: shape: (`*batch_dims`, `*dims`)
#    (...)
#     410         The scores.
#     411     """
# --> 412     return self.__class__.func(**self._prepare_for_functional(h=h, r=r, t=t))
#
# File ~\anaconda3\lib\site-packages\pykeen\nn\functional.py:93, in _add_cuda_warning.<locals>.wrapped(*args, **kwargs)
#      91 except RuntimeError as e:
#      92     if not is_cudnn_error(e):
# ---> 93         raise e
#      94     raise RuntimeError(
#      95         "\nThis code crash might have been caused by a CUDA bug, see "
#      96         "https://github.com/allenai/allennlp/issues/2888, "
#      97         "which causes the code to crash during evaluation mode.\n"
#      98         "To avoid this error, the batch size has to be reduced.",
#      99     ) from e
#
# File ~\anaconda3\lib\site-packages\pykeen\nn\functional.py:90, in _add_cuda_warning.<locals>.wrapped(*args, **kwargs)
#      87 @functools.wraps(func)
#      88 def wrapped(*args, **kwargs):
#      89     try:
# ---> 90         return func(*args, **kwargs)
#      91     except RuntimeError as e:
#      92         if not is_cudnn_error(e):
#
# File ~\anaconda3\lib\site-packages\pykeen\nn\functional.py:153, in conve_interaction(h, r, t, t_bias, input_channels, embedding_height, embedding_width, hr2d, hr1d)
#     150 x = x.view(-1, input_channels, 2 * embedding_height, embedding_width)
#     152 # shape: -1, num_input_channels, 2*height, width
# --> 153 x = hr2d(x)
#     155 # -1, num_output_channels * (2 * height - kernel_height + 1) * (width - kernel_width + 1)
#     156 x = x.view(-1, numpy.prod(x.shape[-3:]))
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# RuntimeError: [enforce fail at ..\c10\core\impl\alloc_cpu.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 26449182720 bytes.

# %%
result.save_to_directory('result_complex')
result2.save_to_directory('result_transe')
# Out:
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172) to file:///C:/Users/shubh/Downloads/result_complex/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: file:///C:/Users/shubh/Downloads/result_complex
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172) to file:///C:/Users/shubh/Downloads/result_transe/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: file:///C:/Users/shubh/Downloads/result_transe

# %%
from pykeen.predict import predict_target

# %% [markdown]
# # USECASE 1 : Upregulated genes prediction for Breast Cancer

# %%
disease_id = run_query("""
MATCH (s:Disease)
WHERE s.name = "breast cancer"
RETURN toString(id(s)) as id
""")['id'][0]

# %%
disease_id
# Out:
# '3099'

# %% [markdown]
# ### Analysis using ComplEx model

# %%
pred = predict_target(
    model=result.model,
    head=disease_id,
    relation="upregulates",
    triples_factory=result.training,
)

# %%
pred
# Out:
# TargetPredictions(df=       tail_id      score tail_label
# 2758      2758  59.933502      12834
# 18403    18403  59.775108       8448
# 10648    10648  56.862106      20901
# 14218    14218  55.041542       4178
# 8279      8279  54.862183       1849
# ...        ...        ...        ...
# 10300    10300 -58.386963      20547
# 2636      2636 -58.652962      12707
# 4389      4389 -59.824844        145
# 3433      3433 -61.008022      13535
# 5323      5323 -61.487949      15467
#
# [19930 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
pred_filtered = pred.filter_triples(training)
pred_filtered
# Out:
# TargetPredictions(df=       tail_id      score tail_label
# 2758      2758  59.933502      12834
# 18403    18403  59.775108       8448
# 10648    10648  56.862106      20901
# 14218    14218  55.041542       4178
# 8279      8279  54.862183       1849
# ...        ...        ...        ...
# 10300    10300 -58.386963      20547
# 2636      2636 -58.652962      12707
# 4389      4389 -59.824844        145
# 3433      3433 -61.008022      13535
# 5323      5323 -61.487949      15467
#
# [19724 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
pred_annotated = pred_filtered.add_membership_columns(training=training, validation=validation, testing=testing)
pred_annotated
# Out:
# TargetPredictions(df=       tail_id      score tail_label  in_training  in_validation  in_testing
# 2758      2758  59.933502      12834        False          False       False
# 18403    18403  59.775108       8448        False          False       False
# 10648    10648  56.862106      20901        False          False       False
# 14218    14218  55.041542       4178        False          False       False
# 8279      8279  54.862183       1849        False          False       False
# ...        ...        ...        ...          ...            ...         ...
# 10300    10300 -58.386963      20547        False          False       False
# 2636      2636 -58.652962      12707        False          False       False
# 4389      4389 -59.824844        145        False          False       False
# 3433      3433 -61.008022      13535        False          False       False
# 5323      5323 -61.487949      15467        False          False       False
#
# [19724 rows x 6 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
df = pred_annotated.df
df
# Out:
#        tail_id      score tail_label  in_training  in_validation  in_testing
# 2758      2758  59.933502      12834        False          False       False
# 18403    18403  59.775108       8448        False          False       False
# 10648    10648  56.862106      20901        False          False       False
# 14218    14218  55.041542       4178        False          False       False
# 8279      8279  54.862183       1849        False          False       False
# ...        ...        ...        ...          ...            ...         ...
# 10300    10300 -58.386963      20547        False          False       False
# 2636      2636 -58.652962      12707        False          False       False
# 4389      4389 -59.824844        145        False          False       False
# 3433      3433 -61.008022      13535        False          False       False
# 5323      5323 -61.487949      15467        False          False       False
#
# [19724 rows x 6 columns]

# %%
candidate_nodes = df[df['in_training'] == False].head(50)['tail_label'].to_list()
print(candidate_nodes)

run_query("""
MATCH (n)
WHERE id(n) = toInteger($disease_id)
UNWIND $candidates as ca
MATCH (c)
WHERE id(c) = toInteger(ca)
MERGE (n)-[:upregulates_C1]->(c)
""", {'disease_id':disease_id, 'candidates': candidate_nodes})
# Out:
# ['12834', '8448', '20901', '4178', '1849', '20929', '3750', '14295', '6213', '5033', '10884', '16716', '7467', '22414', '1553', '13515', '13850', '47', '19972', '13176', '19846', '6672', '14914', '6098', '16141', '10331', '17094', '16839', '5353', '7931', '8264', '655', '10953', '17914', '10828', '7491', '16488', '10506', '11053', '1241', '11333', '13751', '19393', '8340', '15008', '4252', '19739', '7688', '22252', '12429']
# Empty DataFrame
# Columns: []
# Index: []

# %%
run_query("""
MATCH (c:Disease)-[:upregulates_C1]->(d:Gene)
RETURN c.name as Disease, d.name as Gene
""")
# Out:
#           Disease      Gene
# 0   breast cancer    ZBTB22
# 1   breast cancer   COL11A2
# 2   breast cancer     TBX19
# 3   breast cancer    GRPEL2
# 4   breast cancer    OR51E1
# 5   breast cancer    SEC23A
# 6   breast cancer      PRG3
# 7   breast cancer      SMOX
# 8   breast cancer   IGHMBP2
# 9   breast cancer     PPM1A
# 10  breast cancer     FOXN4
# 11  breast cancer      ECI1
# 12  breast cancer     ABCA4
# 13  breast cancer       WAC
# 14  breast cancer   PRAMEF1
# 15  breast cancer     SALL4
# 16  breast cancer    TNFSF4
# 17  breast cancer     JMJD4
# 18  breast cancer      GGA1
# 19  breast cancer     SGPP1
# 20  breast cancer     STAC2
# 21  breast cancer      DDX4
# 22  breast cancer    ZNF317
# 23  breast cancer     COPS3
# 24  breast cancer     KCNRG
# 25  breast cancer    INSIG1
# 26  breast cancer      ATRX
# 27  breast cancer     HACL1
# 28  breast cancer   CYP46A1
# 29  breast cancer     TCEB2
# 30  breast cancer    MAPK15
# 31  breast cancer   C2orf78
# 32  breast cancer      SYCN
# 33  breast cancer    CLDN19
# 34  breast cancer       BSG
# 35  breast cancer   FAM86B1
# 36  breast cancer     CYTH1
# 37  breast cancer       AUH
# 38  breast cancer     ADRM1
# 39  breast cancer      POMK
# 40  breast cancer    TMEM74
# 41  breast cancer   DNAJC17
# 42  breast cancer     SMIM4
# 43  breast cancer  TMEM185A
# 44  breast cancer      GPX2

# %%
run_query("""
MATCH (c:Disease {name: "breast cancer"}),(d:Gene {name:"ZBTB22"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#         [n in nodes(p) | n.name]
# 0  [breast cancer, PIN1, ZBTB22]

# %%
run_query("""
MATCH (c:Disease {name: "breast cancer"}),(d:Gene {name:"COL11A2"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#                    [n in nodes(p) | n.name]
# 0  [breast cancer, HSP90AA1, DDR2, COL11A2]
# 1       [breast cancer, SRC, DDR2, COL11A2]

# %%
run_query("""
MATCH (c:Disease {name: "breast cancer"}),(d:Gene {name:"TBX19"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#                 [n in nodes(p) | n.name]
# 0      [breast cancer, AR, NR5A1, TBX19]
# 1   [breast cancer, BARD1, NR5A1, TBX19]
# 2   [breast cancer, NCOA1, NR5A1, TBX19]
# 3   [breast cancer, NRIP1, NR5A1, TBX19]
# 4  [breast cancer, TRERF1, NR5A1, TBX19]
# 5     [breast cancer, JUN, NR5A1, TBX19]
# 6  [breast cancer, CTNNB1, NR5A1, TBX19]

# %% [markdown]
# ### Analysis using TransE model

# %%
pred2 = predict_target(
    model=result2.model,
    head=disease_id,
    relation="upregulates",
    triples_factory=result2.training,
)

# %%
pred2
# Out:
# TargetPredictions(df=       tail_id      score tail_label
# 4236      4236  -7.233153      14346
# 8449      8449  -7.405909      18659
# 11541    11541  -7.448671      21807
# 10104    10104  -7.582721      20354
# 17244    17244  -7.628639       7273
# ...        ...        ...        ...
# 14747    14747 -14.162211       4719
# 6959      6959 -14.169616      17133
# 12908    12908 -14.182336        283
# 12123    12123 -14.255861      22395
# 19079    19079 -14.690176        913
#
# [19930 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
pred_filtered2 = pred2.filter_triples(training)
pred_filtered2
# Out:
# TargetPredictions(df=       tail_id      score tail_label
# 4236      4236  -7.233153      14346
# 8449      8449  -7.405909      18659
# 11541    11541  -7.448671      21807
# 10104    10104  -7.582721      20354
# 17244    17244  -7.628639       7273
# ...        ...        ...        ...
# 14747    14747 -14.162211       4719
# 6959      6959 -14.169616      17133
# 12908    12908 -14.182336        283
# 12123    12123 -14.255861      22395
# 19079    19079 -14.690176        913
#
# [19724 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
pred_annotated2 = pred_filtered2.add_membership_columns(training=training, validation=validation, testing=testing)
pred_annotated2
# Out:
# TargetPredictions(df=       tail_id      score tail_label  in_training  in_validation  in_testing
# 4236      4236  -7.233153      14346        False          False       False
# 8449      8449  -7.405909      18659        False          False       False
# 11541    11541  -7.448671      21807        False          False       False
# 10104    10104  -7.582721      20354        False          False       False
# 17244    17244  -7.628639       7273        False          False       False
# ...        ...        ...        ...          ...            ...         ...
# 14747    14747 -14.162211       4719        False          False       False
# 6959      6959 -14.169616      17133        False          False       False
# 12908    12908 -14.182336        283        False          False       False
# 12123    12123 -14.255861      22395        False          False       False
# 19079    19079 -14.690176        913        False          False       False
#
# [19724 rows x 6 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='tail', other_columns_fixed_ids=(13167, 9))

# %%
df2 = pred_annotated2.df

candidate_nodes2 = df2[df2['in_training'] == False].head(50)['tail_label'].to_list()

run_query("""
MATCH (n)
WHERE id(n) = toInteger($disease_id)
UNWIND $candidates as ca
MATCH (c)
WHERE id(c) = toInteger(ca)
MERGE (n)-[:upregulates_T1]->(c)
""", {'disease_id':disease_id, 'candidates': candidate_nodes2})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
run_query("""
MATCH (c:Disease)-[:upregulates_T1]->(d:Gene)
RETURN c.name as Disease, d.name as Gene
""")
# Out:
#           Disease     Gene
# 0   breast cancer  TSC22D3
# 1   breast cancer      LBR
# 2   breast cancer  SLC35B1
# 3   breast cancer    STUB1
# 4   breast cancer   DYNLT3
# 5   breast cancer    HACD3
# 6   breast cancer   ANKRA2
# 7   breast cancer    PPP4C
# 8   breast cancer    TRIB3
# 9   breast cancer     CLPX
# 10  breast cancer      MVP
# 11  breast cancer     CD40
# 12  breast cancer    TIMM9
# 13  breast cancer    CD320
# 14  breast cancer    PPARD
# 15  breast cancer    BLVRA
# 16  breast cancer   MTHFD2
# 17  breast cancer    SOCS2
# 18  breast cancer     YBX3
# 19  breast cancer    GDF15
# 20  breast cancer  ARHGEF2
# 21  breast cancer    TUBB6
# 22  breast cancer    NUP85
# 23  breast cancer   PGRMC1
# 24  breast cancer    PTK2B
# 25  breast cancer     AARS
# 26  breast cancer    KAT2A
# 27  breast cancer    CCND3
# 28  breast cancer    CHIC2
# 29  breast cancer   SQSTM1
# 30  breast cancer   IFNAR1
# 31  breast cancer   INSIG1
# 32  breast cancer    HMGCR
# 33  breast cancer   RPS4Y1
# 34  breast cancer    TGFB3
# 35  breast cancer    DDIT4
# 36  breast cancer     RPA1
# 37  breast cancer   UBQLN2
# 38  breast cancer     COG4
# 39  breast cancer     CDK6
# 40  breast cancer    LAMA3
# 41  breast cancer    DDX10
# 42  breast cancer    TXLNA
# 43  breast cancer    CNPY3
# 44  breast cancer    HIF1A
# 45  breast cancer     IRF1
# 46  breast cancer     PFN1
# 47  breast cancer   TUBA1A
# 48  breast cancer    CCNE2
# 49  breast cancer   IGFBP3

# %%
run_query("""
MATCH (c:Disease {name: "breast cancer"}),(d:Gene {name:"STUB1"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#              [n in nodes(p) | n.name]
# 0         [breast cancer, GPI, STUB1]
# 1      [breast cancer, HSPA1B, STUB1]
# 2       [breast cancer, KCNN4, STUB1]
# 3        [breast cancer, TFRC, STUB1]
# 4   [breast cancer, HIST1H2BK, STUB1]
# 5       [breast cancer, FOXQ1, STUB1]
# 6        [breast cancer, KRT8, STUB1]
# 7         [breast cancer, AHR, STUB1]
# 8       [breast cancer, SPRY1, STUB1]
# 9        [breast cancer, RARB, STUB1]
# 10       [breast cancer, FHL2, STUB1]
# 11     [breast cancer, BABAM1, STUB1]
# 12         [breast cancer, F3, STUB1]
# 13        [breast cancer, SRC, STUB1]
# 14      [breast cancer, NR2F6, STUB1]
# 15       [breast cancer, IGF1, STUB1]
# 16       [breast cancer, LSP1, STUB1]
# 17      [breast cancer, ALDOA, STUB1]
# 18      [breast cancer, FGFR2, STUB1]
# 19       [breast cancer, E2F1, STUB1]
# 20       [breast cancer, ARAF, STUB1]
# 21      [breast cancer, STK11, STUB1]
# 22      [breast cancer, ITPR1, STUB1]
# 23       [breast cancer, TARS, STUB1]
# 24       [breast cancer, HADH, STUB1]

# %%
run_query("""
MATCH (c:Disease {name: "breast cancer"}),(d:Gene {name:"DYNLT3"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#              [n in nodes(p) | n.name]
# 0      [breast cancer, KIF2C, DYNLT3]
# 1      [breast cancer, CCNB2, DYNLT3]
# 2       [breast cancer, GLI2, DYNLT3]
# 3     [breast cancer, RAD54L, DYNLT3]
# 4       [breast cancer, CCT5, DYNLT3]
# 5       [breast cancer, PCNA, DYNLT3]
# 6     [breast cancer, CDKN1B, DYNLT3]
# 7       [breast cancer, LDHB, DYNLT3]
# 8      [breast cancer, AURKA, DYNLT3]
# 9      [breast cancer, CDC20, DYNLT3]
# 10     [breast cancer, PYCR1, DYNLT3]
# 11       [breast cancer, CDA, DYNLT3]
# 12  [breast cancer, HSP90AA1, DYNLT3]
# 13      [breast cancer, RPS7, DYNLT3]
# 14     [breast cancer, AURKA, DYNLT3]
# 15     [breast cancer, CASP3, DYNLT3]
# 16    [breast cancer, PPAP2A, DYNLT3]
# 17    [breast cancer, TNFSF4, DYNLT3]
# 18       [breast cancer, ALK, DYNLT3]
# 19      [breast cancer, CDK4, DYNLT3]
# 20      [breast cancer, SMC4, DYNLT3]
# 21     [breast cancer, HJURP, DYNLT3]
# 22     [breast cancer, HIF1A, DYNLT3]
# 23      [breast cancer, EGR1, DYNLT3]
# 24     [breast cancer, ERBB2, DYNLT3]

# %% [markdown]
# # USECASE 2 : Finding compound for one of the genes found in usecase 1

# %%
gene_id = run_query("""
MATCH (s:Gene)
WHERE s.name = "SMC4"
RETURN toString(id(s)) as id
""")['id'][0]

gene_id
# Out:
# '345'

# %% [markdown]
# ### Analysis using Complex model

# %%
pred_d = predict_target(
    model=result.model,
    tail=gene_id,
    relation="downregulates",
    triples_factory=result.training,
)

# %%
pred_d
# Out:
# TargetPredictions(df=       head_id      score head_label
# 15772    15772  58.163986        577
# 17108    17108  54.876755       7141
# 17098    17098  54.188519        713
# 7173      7173  50.922840      17348
# 17709    17709  50.907528        775
# ...        ...        ...        ...
# 12028    12028 -50.278778      22303
# 17948    17948 -51.419437        799
# 4936      4936 -53.656712      15067
# 19476    19476 -53.952469       9538
# 9131      9131 -58.113907      19362
#
# [19930 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
pred_filtered_d = pred_d.filter_triples(training)
pred_filtered_d
# Out:
# TargetPredictions(df=       head_id      score head_label
# 15772    15772  58.163986        577
# 17108    17108  54.876755       7141
# 17098    17098  54.188519        713
# 7173      7173  50.922840      17348
# 17709    17709  50.907528        775
# ...        ...        ...        ...
# 12028    12028 -50.278778      22303
# 17948    17948 -51.419437        799
# 4936      4936 -53.656712      15067
# 19476    19476 -53.952469       9538
# 9131      9131 -58.113907      19362
#
# [19903 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
pred_annotated_d = pred_filtered_d.add_membership_columns(training=training, validation=validation, testing=testing)
pred_annotated_d
# Out:
# TargetPredictions(df=       head_id      score head_label  in_training  in_validation  in_testing
# 15772    15772  58.163986        577        False          False       False
# 17108    17108  54.876755       7141        False          False       False
# 17098    17098  54.188519        713        False          False       False
# 7173      7173  50.922840      17348        False          False       False
# 17709    17709  50.907528        775        False          False       False
# ...        ...        ...        ...          ...            ...         ...
# 12028    12028 -50.278778      22303        False          False       False
# 17948    17948 -51.419437        799        False          False       False
# 4936      4936 -53.656712      15067        False          False       False
# 19476    19476 -53.952469       9538        False          False       False
# 9131      9131 -58.113907      19362        False          False       False
#
# [19903 rows x 6 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
df_d = pred_annotated_d.df

candidate_nodes_d = df_d[df_d['in_training'] == False].head(50)['head_label'].to_list()

candidate_nodes_d
# Out:
# ['577',
#  '7141',
#  '713',
#  '17348',
#  '775',
#  '11449',
#  '12071',
#  '17355',
#  '5193',
#  '9257',
#  '11379',
#  '21727',
#  '10982',
#  '16427',
#  '917',
#  '15790',
#  '8973',
#  '22400',
#  '18623',
#  '1888',
#  '18026',
#  '16346',
#  '13416',
#  '1754',
#  '18365',
#  '10434',
#  '6207',
#  '8783',
#  '13802',
#  '21577',
#  '898',
#  '2921',
#  '16026',
#  '888',
#  '2907',
#  '2977',
#  '4478',
#  '10619',
#  '17246',
#  '22502',
#  '12141',
#  '9284',
#  '8336',
#  '6889',
#  '16525',
#  '10784',
#  '21113',
#  '20699',
#  '16516',
#  '2461']

# %%
run_query("""
MATCH (n)
WHERE id(n) = toInteger($gene_id)
UNWIND $candidates as ca
MATCH (c)
WHERE id(c) = toInteger(ca) and "Compound" in labels(c)
MERGE (c)-[:downreg_c_usecase2]->(n)
""", {'gene_id':gene_id, 'candidates': candidate_nodes_d})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
run_query("""
MATCH (c:Compound)-[:downreg_c_usecase2]->(d:Gene)
RETURN c.name as Compound, d.name as Gene
""")
# Out:
#         Compound  Gene
# 0  Cyclothiazide  SMC4
# 1     Prednisone  SMC4
# 2       Thiotepa  SMC4

# %% [markdown]
# ### Analysis using TransE model

# %%
pred_d = predict_target(
    model=result2.model,
    tail=gene_id,
    relation="downregulates",
    triples_factory=result2.training,
)
pred_d
# Out:
# TargetPredictions(df=       head_id      score head_label
# 4040      4040  -6.987144      14149
# 7709      7709  -7.176988      17897
# 14711    14711  -7.318759       4685
# 285        285  -7.319709      10290
# 2539      2539  -7.341794      12608
# ...        ...        ...        ...
# 12490    12490 -14.326984       2395
# 12025    12025 -14.328463       2230
# 13991    13991 -14.413631       3949
# 16919    16919 -14.427435       6947
# 17496    17496 -14.738400       7532
#
# [19930 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
pred_filtered_d = pred_d.filter_triples(training)
pred_filtered_d
# Out:
# TargetPredictions(df=       head_id      score head_label
# 4040      4040  -6.987144      14149
# 7709      7709  -7.176988      17897
# 2539      2539  -7.341794      12608
# 754        754  -7.447429      10779
# 11483    11483  -7.452220      21750
# ...        ...        ...        ...
# 12490    12490 -14.326984       2395
# 12025    12025 -14.328463       2230
# 13991    13991 -14.413631       3949
# 16919    16919 -14.427435       6947
# 17496    17496 -14.738400       7532
#
# [19903 rows x 3 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
pred_annotated_d = pred_filtered_d.add_membership_columns(training=training, validation=validation, testing=testing)
pred_annotated_d
# Out:
# TargetPredictions(df=       head_id      score head_label  in_training  in_validation  in_testing
# 4040      4040  -6.987144      14149        False          False       False
# 7709      7709  -7.176988      17897        False          False       False
# 2539      2539  -7.341794      12608        False          False        True
# 754        754  -7.447429      10779        False          False       False
# 11483    11483  -7.452220      21750        False          False       False
# ...        ...        ...        ...          ...            ...         ...
# 12490    12490 -14.326984       2395        False          False       False
# 12025    12025 -14.328463       2230        False          False       False
# 13991    13991 -14.413631       3949        False          False       False
# 16919    16919 -14.427435       6947        False          False       False
# 17496    17496 -14.738400       7532        False          False       False
#
# [19903 rows x 6 columns], factory=TriplesFactory(num_entities=19930, num_relations=10, create_inverse_triples=False, num_triples=450172), target='head', other_columns_fixed_ids=(4, 13507))

# %%
df_d = pred_annotated_d.df

candidate_nodes_d = df_d[df_d['in_training'] == False].head(50)['head_label'].to_list()

candidate_nodes_d
# Out:
# ['14149',
#  '17897',
#  '12608',
#  '10779',
#  '21750',
#  '18131',
#  '9349',
#  '17133',
#  '13726',
#  '16565',
#  '11388',
#  '1278',
#  '5972',
#  '913',
#  '22096',
#  '3099',
#  '6832',
#  '19130',
#  '11213',
#  '283',
#  '17046',
#  '13667',
#  '19473',
#  '1796',
#  '20343',
#  '9052',
#  '15522',
#  '11912',
#  '14874',
#  '10838',
#  '322',
#  '10808',
#  '7714',
#  '15833',
#  '5070',
#  '4407',
#  '13047',
#  '18634',
#  '9825',
#  '19270',
#  '6113',
#  '6216',
#  '1303',
#  '22395',
#  '4360',
#  '1595',
#  '10144',
#  '4437',
#  '9836',
#  '20460']

# %%
run_query("""
MATCH (n)
WHERE id(n) = toInteger($gene_id)
UNWIND $candidates as ca
MATCH (c)
WHERE id(c) = toInteger(ca) and "Compound" in labels(c)
MERGE (c)-[:downreg_t_usecase2]->(n)
""", {'gene_id':gene_id, 'candidates': candidate_nodes_d})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
run_query("""
MATCH (c:Compound)-[:downreg_t_usecase2]->(d:Gene)
RETURN c.name as Compound, d.name as Gene
""")
# Out:
#                   Compound  Gene
# 0              Vemurafenib  SMC4
# 1             Pitavastatin  SMC4
# 2              Azacitidine  SMC4
# 3                Digitoxin  SMC4
# 4                Bisacodyl  SMC4
# 5              Clofarabine  SMC4
# 6                  Digoxin  SMC4
# 7             Thioridazine  SMC4
# 8             Treprostinil  SMC4
# 9                Sirolimus  SMC4
# 10              Vorinostat  SMC4
# 11             Varenicline  SMC4
# 12            Isotretinoin  SMC4
# 13            Dactinomycin  SMC4
# 14              Nizatidine  SMC4
# 15             Albendazole  SMC4
# 16             Fluvastatin  SMC4
# 17           Betamethasone  SMC4
# 18              Bortezomib  SMC4
# 19               Podofilox  SMC4
# 20                 Ouabain  SMC4
# 21            Daunorubicin  SMC4
# 22             Clopidogrel  SMC4
# 23               Bupropion  SMC4
# 24              Everolimus  SMC4
# 25              Trametinib  SMC4
# 26             Pentamidine  SMC4
# 27              Paclitaxel  SMC4
# 28             Simvastatin  SMC4
# 29                Busulfan  SMC4
# 30             Mebendazole  SMC4
# 31       Homoharringtonine  SMC4
# 32  Fluticasone Propionate  SMC4
# 33              Disulfiram  SMC4

# %%
run_query("""
MATCH (c:Gene {name: "SMC4"}),(d:Compound {name:"Vemurafenib"})
WITH c,d
MATCH p=AllShortestPaths((c)-[r:binds|regulates|interacts|upregulates|downregulates|associates*1..4]-(d))
RETURN [n in nodes(p) | n.name] LIMIT 25
""")
# Out:
#          [n in nodes(p) | n.name]
# 0     [SMC4, SLC2A6, Vemurafenib]
# 1     [SMC4, INPP4B, Vemurafenib]
# 2      [SMC4, CREG1, Vemurafenib]
# 3       [SMC4, UGDH, Vemurafenib]
# 4       [SMC4, NBR1, Vemurafenib]
# 5        [SMC4, CBS, Vemurafenib]
# 6       [SMC4, PAN2, Vemurafenib]
# 7      [SMC4, HSPA8, Vemurafenib]
# 8      [SMC4, TUBB3, Vemurafenib]
# 9      [SMC4, KAT6B, Vemurafenib]
# 10    [SMC4, TUBB2A, Vemurafenib]
# 11      [SMC4, RBKS, Vemurafenib]
# 12     [SMC4, DNM1L, Vemurafenib]
# 13     [SMC4, VDAC1, Vemurafenib]
# 14    [SMC4, CCDC86, Vemurafenib]
# 15  [SMC4, EIF4EBP1, Vemurafenib]
# 16   [SMC4, TBC1D31, Vemurafenib]
# 17   [SMC4, HSD17B8, Vemurafenib]
# 18   [SMC4, ATP6V0B, Vemurafenib]
# 19    [SMC4, CDKN1A, Vemurafenib]
# 20    [SMC4, MTHFD2, Vemurafenib]
# 21     [SMC4, TIMP1, Vemurafenib]
# 22      [SMC4, WARS, Vemurafenib]
# 23     [SMC4, PUF60, Vemurafenib]
# 24   [SMC4, DNTTIP2, Vemurafenib]
